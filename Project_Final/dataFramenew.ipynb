# %%
import json
import pandas as pd   
import yaml
import numpy as np
import sqlite3
import sqlalchemy
from sqlalchemy import create_engine
data = []
c = 0

with open('meta_Clothing_Shoes_and_Jewelry.jsonl') as f:
    for line in f:
        data.append(json.loads(line))
        c+=1        
        if c == 17000:
            break

# %%
data_df = pd.DataFrame(data)

# %%
data_df
# Out:
#         main_category                                              title  \
# 0      AMAZON FASHION  BALEAF Women's Long Sleeve Zip Beach Coverup U...
# 1      AMAZON FASHION     Merrell Work Moab 2 Vent Waterproof SR Boulder
# 2      AMAZON FASHION                        SAS Women's, Relaxed Sandal
# 3      AMAZON FASHION  SheIn Women's Basic Stretch Plaid Mini Bodycon...
# 4      AMAZON FASHION         Michael Kors Cindy, Women’s Cross-Body Bag
# ...               ...                                                ...
# 16995  AMAZON FASHION  PRETTYGARDEN Women's Zip Up Y2K Hoodies Casual...
# 16996  AMAZON FASHION  Add Your Own Text and Design Custom Personaliz...
# 16997  AMAZON FASHION          Red Rock Outdoor Gear - Shemagh Head Wrap
# 16998  AMAZON FASHION                       Metallic Wrist Length Gloves
# 16999  AMAZON FASHION  Venshine Mens Walking Shoes Leather Lightweigh...
#
#        average_rating  rating_number  \
# 0                 4.2            422
# 1                 2.7              4
# 2                 4.7            618
# 3                 3.8            999
# 4                 4.5              6
# ...               ...            ...
# 16995             4.4            268
# 16996             4.4           2821
# 16997             4.5            550
# 16998             3.4             12
# 16999             4.3           3922
#
#                                                 features  \
# 0      [90% Polyester, 10% Spandex, Zipper closure, M...
# 1                                          [Rubber sole]
# 2      [Made in the USA, Suede sole, Heel measures ap...
# 3      [Zipper closure, Fabric has some stretch; Plea...
# 4      [Leather, 9-1/2" W x 5-1/4" H x 2-1/4" D, Inte...
# ...                                                  ...
# 16995  [80% Polyester, 20% Cotton, Imported, Zipper c...
# 16996  [50% Cotton, 50% Polyester, Made in the USA or...
# 16997  [100% Cotton, Made in the USA or Imported, Han...
# 16998  [100% Nylon, Pull On closure, Air Dry,Hand Was...
# 16999  [Leather sole, The unique vent design and foam...
#
#                                              description   price  \
# 0                                                     []   31.99
# 1                                                     []     NaN
# 2      [Unwind, leave your worries behind, and simply...  188.95
# 3                                                     []   12.99
# 4      [Adjustable crossbody strap with 24"-26" drop ...     NaN
# ...                                                  ...     ...
# 16995                                                 []   42.99
# 16996                                                 []   45.90
# 16997  [The tactical Shemagh head wrap by Red Rock Ou...   10.59
# 16998  [Be outrageous with your new flashy metallic g...   13.05
# 16999                                                 []   59.99
#
#                                                   images  \
# 0      [{'thumb': 'https://m.media-amazon.com/images/...
# 1      [{'thumb': 'https://m.media-amazon.com/images/...
# 2      [{'thumb': 'https://m.media-amazon.com/images/...
# 3      [{'thumb': 'https://m.media-amazon.com/images/...
# 4      [{'thumb': 'https://m.media-amazon.com/images/...
# ...                                                  ...
# 16995  [{'thumb': 'https://m.media-amazon.com/images/...
# 16996  [{'thumb': 'https://m.media-amazon.com/images/...
# 16997  [{'thumb': 'https://m.media-amazon.com/images/...
# 16998  [{'thumb': 'https://m.media-amazon.com/images/...
# 16999  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                                                   videos  \
# 0      [{'title': 'Women's UPF 50+ Front Zip Beach Co...
# 1                                                     []
# 2                                                     []
# 3      [{'title': 'SUPER CUTE plaid skirt!', 'url': '...
# 4                                                     []
# ...                                                  ...
# 16995  [{'title': 'Sports Coats With Pockets', 'url':...
# 16996                                                 []
# 16997                                                 []
# 16998  [{'title': 'Metallic costume gloves', 'url': '...
# 16999  [{'title': 'VENSHINE Mens Walking Shoes Leathe...
#
#                        store  \
# 0                     BALEAF
# 1                    Merrell
# 2                        SAS
# 3                      SheIn
# 4               Michael Kors
# ...                      ...
# 16995           PRETTYGARDEN
# 16996            City Shirts
# 16997  Red Rock Outdoor Gear
# 16998             Greatlookz
# 16999               Venshine
#
#                                               categories  \
# 0      [Clothing, Shoes & Jewelry, Women, Clothing, S...
# 1      [Clothing, Shoes & Jewelry, Women, Shoes, Outd...
# 2      [Clothing, Shoes & Jewelry, Women, Shoes, Sand...
# 3      [Clothing, Shoes & Jewelry, Novelty & More, Cl...
# 4      [Clothing, Shoes & Jewelry, Women, Handbags & ...
# ...                                                  ...
# 16995  [Clothing, Shoes & Jewelry, Women, Clothing, C...
# 16996  [Clothing, Shoes & Jewelry, Novelty & More, Cl...
# 16997         [Clothing, Shoes & Jewelry, Men, Clothing]
# 16998  [Clothing, Shoes & Jewelry, Women, Accessories...
# 16999  [Clothing, Shoes & Jewelry, Men, Shoes, Loafer...
#
#                                                  details parent_asin  \
# 0      {'Department': 'womens', 'Date First Available...  B09X1MRDN6
# 1      {'Package Dimensions': '14.02 x 9.29 x 4.8 inc...  B073C4Q7W8
# 2      {'Product Dimensions': '10 x 15 x 6 inches; 2 ...  B0944VG4Y4
# 3      {'Department': 'womens', 'Date First Available...  B08JGGF5TJ
# 4      {'Is Discontinued By Manufacturer': 'No', 'Pro...  B00ZQMM6BI
# ...                                                  ...         ...
# 16995  {'Package Dimensions': '8 x 5 x 2 inches; 4.8 ...  B0BGP3WZN8
# 16996  {'Is Discontinued By Manufacturer': 'No', 'Dep...  B071HSTPDV
# 16997  {'Product Dimensions': '5 x 5 x 5 inches; 6.4 ...  B082228Q4K
# 16998  {'Department': 'womens', 'Date First Available...  B004L0Y4EI
# 16999  {'Package Dimensions': '13.39 x 7.48 x 4.33 in...  B09MKWLLQR
#
#       bought_together subtitle  author
# 0                None      NaN     NaN
# 1                None      NaN     NaN
# 2                None      NaN     NaN
# 3                None      NaN     NaN
# 4                None      NaN     NaN
# ...               ...      ...     ...
# 16995            None      NaN     NaN
# 16996            None      NaN     NaN
# 16997            None      NaN     NaN
# 16998            None      NaN     NaN
# 16999            None      NaN     NaN
#
# [17000 rows x 16 columns]

# %%
data_df['gender'] = data_df['categories'].str[1]
data_df['type'] = data_df['categories'].str[2]
data_df['misc'] = data_df['categories'].str[3]

# %%
data_df = data_df.drop(['features', 'images', 'description', 'videos', 'categories', 'parent_asin', 'details', 'bought_together', 'subtitle', 'author'], axis=1)

data_df.dropna(subset=['price'], inplace=True)

# %%
data_df.reset_index(inplace = True, drop=False)
data_df.rename(columns={'index': "id"})
# Out:
#          id   main_category  \
# 0         0  AMAZON FASHION
# 1         2  AMAZON FASHION
# 2         3  AMAZON FASHION
# 3         7  AMAZON FASHION
# 4         8  AMAZON FASHION
# ...     ...             ...
# 9227  16995  AMAZON FASHION
# 9228  16996  AMAZON FASHION
# 9229  16997  AMAZON FASHION
# 9230  16998  AMAZON FASHION
# 9231  16999  AMAZON FASHION
#
#                                                   title  average_rating  \
# 0     BALEAF Women's Long Sleeve Zip Beach Coverup U...             4.2
# 1                           SAS Women's, Relaxed Sandal             4.7
# 2     SheIn Women's Basic Stretch Plaid Mini Bodycon...             3.8
# 3     Costume Gloves Kids Girls Boys Princess Dress ...             4.4
# 4     Chowsir Women Fashion V-Neck Formal Lace Eveni...             4.3
# ...                                                 ...             ...
# 9227  PRETTYGARDEN Women's Zip Up Y2K Hoodies Casual...             4.4
# 9228  Add Your Own Text and Design Custom Personaliz...             4.4
# 9229          Red Rock Outdoor Gear - Shemagh Head Wrap             4.5
# 9230                       Metallic Wrist Length Gloves             3.4
# 9231  Venshine Mens Walking Shoes Leather Lightweigh...             4.3
#
#       rating_number   price                  store          gender  \
# 0               422   31.99                 BALEAF           Women
# 1               618  188.95                    SAS           Women
# 2               999   12.99                  SheIn  Novelty & More
# 3                30    9.59               unbrands  Novelty & More
# 4               127   22.19                Chowsir           Women
# ...             ...     ...                    ...             ...
# 9227            268   42.99           PRETTYGARDEN           Women
# 9228           2821   45.90            City Shirts  Novelty & More
# 9229            550   10.59  Red Rock Outdoor Gear             Men
# 9230             12   13.05             Greatlookz           Women
# 9231           3922   59.99               Venshine             Men
#
#              type                          misc
# 0        Clothing         Swimsuits & Cover Ups
# 1           Shoes                       Sandals
# 2        Clothing                       Novelty
# 3        Clothing                       Novelty
# 4        Clothing                       Dresses
# ...           ...                           ...
# 9227     Clothing        Coats, Jackets & Vests
# 9228     Clothing                       Novelty
# 9229     Clothing                           NaN
# 9230  Accessories  Special Occasion Accessories
# 9231        Shoes            Loafers & Slip-Ons
#
# [9232 rows x 10 columns]

# %%
data_df['type'].unique()
# Out:
# array(['Clothing', 'Shoes', 'Uniforms, Work & Safety', 'Accessories',
#        'Kids & Baby', 'Backpacks', 'Women', 'Jewelry Accessories',
#        'Jewelry', nan, 'Running', 'Baby Girls', 'Men',
#        'Travel Accessories', 'Handbags & Wallets', 'Cheerleading',
#        'Baby Boys', 'Watches', 'Dance', 'Cycling', 'Soccer & Futsal',
#        'Skiing', 'Watch Accessories', 'Basketball',
#        'Hiking & Outdoor Recreation', 'Travel Totes',
#        'Competitive Swimwear', 'Maternity', 'School Uniforms',
#        'Umbrellas', 'Martial Arts', 'Gym Bags', 'Yoga',
#        'Shoe Care & Accessories', 'Waist Packs', 'Girls',
#        'Equestrian Sports', 'Props', 'Ice Hockey', 'Baseball',
#        'Messenger Bags', 'Travel Duffels', "Men's Swimwear", 'Luggage',
#        'Golf', 'Boys Shoes', 'Boys', 'Gymnastics', 'Softball',
#        'Girls Tops & Tees 1', 'Ice Skating', 'Food Service Uniforms',
#        'American Football', 'Snowboarding', 'Jackets and Coats',
#        'Womens GenZ Shoes', 'Shoe Care Treatments & Dyes',
#        'TEST W GENZ SHOES', "Boys' Swimwear", 'Volleyball',
#        "Women's fashion Made in Italy", 'Boys Sneakers (no fs)',
#        'Girls Boots, Clogs & Mules', 'Tennis', 'Girls Jackets and Coats',
#        'Cricket', 'Boxing', 'Makeup, Facial Hair & Adhesives'],
#       dtype=object)

# %%
data_full = data_df[["index", "main_category", "title", "average_rating", "rating_number", "price", "store", "gender", "type", "misc"]]

engine = create_engine('sqlite:///instance/amazon.db')
data_full.to_sql('Inventory', con=engine, index=False, if_exists='replace')
# Out:
# 9232

# %%
data_df.head(20)
# Out:
#     index   main_category                                              title  \
# 0       0  AMAZON FASHION  BALEAF Women's Long Sleeve Zip Beach Coverup U...
# 1       2  AMAZON FASHION                        SAS Women's, Relaxed Sandal
# 2       3  AMAZON FASHION  SheIn Women's Basic Stretch Plaid Mini Bodycon...
# 3       7  AMAZON FASHION  Costume Gloves Kids Girls Boys Princess Dress ...
# 4       8  AMAZON FASHION  Chowsir Women Fashion V-Neck Formal Lace Eveni...
# 5      10  AMAZON FASHION  Amazon Essentials Women's Surplice Dress (Avai...
# 6      11  AMAZON FASHION  Fotociti Yoga Shorts for Women – 5" High Waist...
# 7      12  AMAZON FASHION       327th Airborne Infantry Regiment Patch Recon
# 8      15  AMAZON FASHION            Olga Women's Sheer Leaves Minimizer Bra
# 9      16  AMAZON FASHION  Girls Winter Warm Jacket Coat Windbreaker with...
# 10     17  AMAZON FASHION              ASICS Women's GT-2000 9 Running Shoes
# 11     19  AMAZON FASHION                  Skechers USA Men's Proven Slipper
# 12     20  AMAZON FASHION  Men's Stretch Zipper Pocket Shorts Outer Thigh...
# 13     22  AMAZON FASHION  Lovaru Womens Boho Knit Cardigan Loose Lightwe...
# 14     23  AMAZON FASHION  heipeiwa Women Sandals Bow Flowers Flats Jelly...
# 15     25  AMAZON FASHION  Joyci Fashion Faux Rabbit Fur Collar Shawl Wra...
# 16     27  AMAZON FASHION  Women Sexy Criss Cross Front Spaghetti Strap B...
# 17     28      All Beauty  Hipsy Women's Stretchy Xflex Hairband Headband...
# 18     29  AMAZON FASHION  Blouses for Women Fashion, Casual Long Sleeve ...
# 19     33  AMAZON FASHION  ELLEN TRACY Women’s Hi Cut Brief Panties Breat...
#
#     average_rating  rating_number   price               store          gender  \
# 0              4.2            422   31.99              BALEAF           Women
# 1              4.7            618  188.95                 SAS           Women
# 2              3.8            999   12.99               SheIn  Novelty & More
# 3              4.4             30    9.59            unbrands  Novelty & More
# 4              4.3            127   22.19             Chowsir           Women
# 5              4.4           7096   19.92   Amazon Essentials           Women
# 6              4.5           2911   15.99            Fotociti           Women
# 7              5.0              1   10.50       Popular Patch             Men
# 8              4.1            828   25.20                Olga           Women
# 9              4.5            200   30.99           FunnyPaja           Girls
# 10             4.5           3626   99.95               ASICS           Women
# 11             4.3             35   34.44  Skechers USA Men's             Men
# 12             4.4           1256   19.79            Satankud             Men
# 13             4.1            484   28.88              Lovaru           Women
# 14             4.1             57   18.99            heipeiwa           Women
# 15             4.0            126   13.99               Joyci           Women
# 16             4.5           2224   25.99              Melody           Women
# 17             4.3              8   16.99               Hipsy           Women
# 18             4.2          26384   26.99            BIG DART           Women
# 19             4.7           2584   17.99         ELLEN TRACY           Women
#
#                        type                      misc
# 0                  Clothing     Swimsuits & Cover Ups
# 1                     Shoes                   Sandals
# 2                  Clothing                   Novelty
# 3                  Clothing                   Novelty
# 4                  Clothing                   Dresses
# 5                  Clothing                   Dresses
# 6                  Clothing                    Active
# 7   Uniforms, Work & Safety                  Clothing
# 8                  Clothing  Lingerie, Sleep & Lounge
# 9                  Clothing           Jackets & Coats
# 10                    Shoes                  Athletic
# 11                    Shoes                  Slippers
# 12                 Clothing                    Active
# 13                 Clothing                  Sweaters
# 14                    Shoes                   Sandals
# 15              Accessories           Scarves & Wraps
# 16                 Clothing      Tops, Tees & Blouses
# 17              Accessories               Hats & Caps
# 18                 Clothing      Tops, Tees & Blouses
# 19                 Clothing  Lingerie, Sleep & Lounge

# %%
cust_stats_f = data_df[["customer_id", "total_orders", "total_items", "total_spent"]]

engine = create_engine('sqlite:///PEP1_db.db')
orders_f.to_sql('orders', con=engine, index=False, if_exists='replace')

# %%
data_df.to_csv("Clothing_Data_small.csv")

# %%
with open('meta_Clothing_Shoes_and_Jewelry.jsonl', 'r') as json_file:
    data = json.load(json_file)

    chunk_size = len(data) // 1000

    for i in range(3):
        print(i)
        # with open(f"part{i}.json", 'w') as outfile:
        #     outfile.write(json.dumps(data[i*chunk_size:(i+1)*chunk_size]))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[8], line 2
#       1 with open('meta_Clothing_Shoes_and_Jewelry.jsonl', 'r') as json_file:
# ----> 2     data = json.load(json_file)
#       4     chunk_size = len(data) // 1000
#       6     for i in range(3):
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.752.0_x64__qbz5n2kfra8p0\Lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# MemoryError:
